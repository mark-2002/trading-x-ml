# %%
import pandas as pd 
import numpy as np
import yfinance as yf

# %% [markdown]
# The rules for the strategy are:
# 1. Select all stocks near the market open whose returns from their
# previous day’s lows to today’s opens are lower than one standard
#
# deviation. The standard deviation is computed using the daily close-
# to-close returns of the last 90 days. These are the stocks that “gapped
#
# down.”
# 2. Narrow down this list of stocks by requiring their open prices to be
# higher than the 20-day moving average of the closing prices.
#
# 3. Buy the 10 stocks within this list that have the lowest returns from their
# previous day’s lows. If the list has fewer than 10 stocks, then buy the
# entire list.
#
# 4. Liquidate all positions at the market close.

# %%
topN = 10
entryZscore  = 1
lookback = 20

# %%
#1

import yfinance as yf
import pandas as pd

# Get the list of tickers for S&P 500
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol']

# Get historical data for each ticker
data = {}
returns = {}
for ticker in sp500_tickers:
    try:
        stock = yf.Ticker(ticker)
        hist_data = stock.history(period='5y')
        data[ticker] = hist_data[['Open', 'Low', 'Close']]
        returns[ticker] = hist_data['Close'].pct_change()
    except:
        print(f"Error retrieving data for {ticker}")

# Concatenate the data into a single DataFrame
df = pd.concat(data.values(), keys=data.keys())

# Extract the open, low, and close prices
op = df['Open'].unstack()
lo = df['Low'].unstack()
cl = df['Close'].unstack()

# Display the shape of the arrays
print(f"op shape: {op.shape}, lo shape: {lo.shape}, cl shape: {cl.shape}")

# %%
sp_returns = pd.concat(returns.values(),keys=returns.keys())
sp_returns = pd.DataFrame(sp_returns)

# %%
sp_returns

# %%
moving_std_deviaiton = sp_returns.rolling(90).std().shift(1)

moving_std_deviaiton = moving_std_deviaiton.rename(columns={"Close":"Returns"})

moving_std_deviaiton

# %%
moving_std_deviaiton

# %%
sp_df = pd.concat([df,moving_std_deviaiton],axis = 1)
sp_df

# %%
'''Shifting the rolling standard deviation by one day is often done to align the calculated standard deviation with the returns data in a way that allows for meaningful analysis. Here's why this is commonly done:

1. **Avoiding Lookahead Bias**: When calculating a rolling statistic (like a rolling standard deviation), you are essentially using data up to a certain point in time to make calculations for that point and potentially future points. Shifting the result by one day ensures that the calculated standard deviation corresponds to the returns for the next day, avoiding a lookahead bias where the statistic is used to make decisions based on future data.

2. **Aligning Data for Analysis**: In many cases, you want to compare the current day's returns or other metrics with the historical data. Shifting the rolling standard deviation by one day aligns it with the returns data, making it easier to analyze relationships between volatility (as measured by the standard deviation) and returns.

3. **Consistency in Time Series Analysis**: Shifting the result by one day maintains consistency in time series analysis. For example, if you are calculating correlations or other metrics between different time series (e.g., returns and standard deviation), aligning the data correctly ensures that the analysis is meaningful and avoids introducing errors or biases.

Overall, shifting the rolling standard deviation by one day is a common practice to ensure that the calculated statistic is aligned with the data it is intended to analyze, avoiding biases and ensuring consistency in time series analysis.'''

buyPrice = sp_df['Low'].shift(1)*(1-entryZscore*sp_df['Returns'])

buyPrice.shape

# %%
'''This line of code calculates a metric called `op_lo` which represents the percentage change from the previous day's low price to the current day's open price for each stock. Here's a breakdown:

- `sp_df['Open']`: This refers to the open prices of the stocks in the DataFrame `sp_df`.

- `sp_df['Low'].shift(1)`: This shifts the low prices (`Low`) of the stocks by one day. This is done to use the low prices from the previous day.

- `(sp_df['Open'] - sp_df['Low'].shift(1))`: This calculates the difference between the current day's open price and the previous day's low price for each stock.

- `(sp_df['Open'] - sp_df['Low'].shift(1))/sp_df['Low'].shift(1)`: Finally, this division calculates the percentage change from the previous day's low price to the current day's open price. This is done by dividing the difference calculated above by the previous day's low price and multiplying by 100 to express the result as a percentage.

Overall, the `op_lo` metric provides insight into how much the price has moved from the previous day's low to the current day's open, expressed as a percentage of the previous day's low price. This can be useful in analyzing intraday price movements and volatility.'''

op_lo = (sp_df['Open'] - sp_df['Low'].shift(1))/sp_df['Low'].shift(1)

op_lo = op_lo

# %%
df['Open'].shape

# %%
'''This line of code calculates the rolling mean of the closing prices (`Close`) of the stocks over a specified lookback period, and then shifts the result by one day. Let's break it down:

- `df['Close']`: This refers to the closing prices of the stocks in the DataFrame `df`.

- `.rolling(lookback)`: This method calculates a rolling window of the specified `lookback` period (e.g., 20 days) over the data. For each day, it includes the closing prices of the current day and the previous `lookback-1` days.

- `.mean()`: This calculates the mean (average) of the closing prices within each rolling window. So, for each day, you get the average closing price over the previous `lookback` days.

- `.shift(1)`: This shifts the result by one day. The purpose of this shift is to align the rolling mean with the returns for the next day. For example, the rolling mean calculated for day 100 will be aligned with the returns for day 101.

Reasoning:

In the context of the other codes you mentioned, this line of code is used to calculate a moving average of the closing prices over a specified lookback period. The moving average is then used as a reference point or threshold for making trading decisions. Comparing the current day's open price to the previous day's low price and the moving average allows for the identification of stocks whose prices are potentially at attractive levels for buying.'''


moving_average = df['Close'].rolling(lookback).mean().shift(1)
moving_average.shape

# %%
pnl = pd.Series(index=df['Close'].index, dtype=float)
positionTable = pd.DataFrame(index=df['Close'].index, columns=df[['Close']].columns)

# %%
op_lo.to_frame()
# Out:
#                                       0
#     Date
# MMM 2019-06-21 00:00:00-04:00       NaN
#     2019-06-24 00:00:00-04:00  0.004171
#     2019-06-25 00:00:00-04:00 -0.000519
#     2019-06-26 00:00:00-04:00  0.006247
#     2019-06-27 00:00:00-04:00  0.004601
# ...                                 ...
# ZTS 2024-06-13 00:00:00-04:00  0.006121
#     2024-06-14 00:00:00-04:00 -0.002108
#     2024-06-17 00:00:00-04:00 -0.003493
#     2024-06-18 00:00:00-04:00  0.018408
#     2024-06-20 00:00:00-04:00  0.006222
#
# [622575 rows x 1 columns]

# %%
import pandas as pd

# Assuming these are your existing DataFrames
# df, op_lo, buyPrice, moving_average

# Initialize an empty list to store the boolean masks
stocks_to_buy_list = []

# Iterate over the range of indices
for t in range(1, len(df['Close'])):
    stocks_to_buy_t = op_lo.iloc[[t]].notnull() & (df['Open'].iloc[t] < buyPrice.iloc[t]) & (df['Open'].iloc[t] > moving_average.iloc[t])
    stocks_to_buy_list.append(stocks_to_buy_t)
    print(stocks_to_buy_t)

# Concatenate the list of boolean masks into a single DataFrame
stocks_to_buy_df = pd.concat(stocks_to_buy_list, axis=1)

# Transpose the DataFrame if needed
#stocks_to_buy_df = stocks_to_buy_df.T

print(stocks_to_buy_list)

# %%
type(stocks_to_buy_list)

# %%
stocks_to_buy_list
# Out:
# [     Date
#  MMM  2019-06-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-06-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-06-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-06-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-06-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-07-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-08-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-09-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-10-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-15 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-20 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-25 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-26 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-11-29 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-20 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-26 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-30 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2019-12-31 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-15 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-28 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-29 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-30 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-01-31 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-20 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-25 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-26 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-02-28 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-03-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-04-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-05-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-06-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-07-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-08-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-21 00:00:00-04:00    True
#  dtype: bool,
#       Date
#  MMM  2020-09-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-09-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-10-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-20 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-25 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-11-30 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-01 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-15 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-28 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-29 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-30 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2020-12-31 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-15 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-20 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-25 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-26 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-28 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-01-29 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-01 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-25 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-02-26 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-01 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-03-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-04-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-05-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-06-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-07-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2021-08-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
# ...
#  MMM  2022-09-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-09-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-25 00:00:00-04:00    True
#  dtype: bool,
#       Date
#  MMM  2022-10-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-10-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-15 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-25 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-28 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-29 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-11-30 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-01 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-15 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-20 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-28 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-29 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2022-12-30 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-04 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-05 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-11 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-12 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-18 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-19 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-20 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-25 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-26 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-30 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-01-31 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-01 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-13 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-14 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-15 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-16 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-17 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-21 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-22 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-23 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-24 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-27 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-02-28 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-01 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-02 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-03 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-06 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-07 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-08 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-09 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-10 00:00:00-05:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-29 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-03-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-13 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-14 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-20 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-21 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-27 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-04-28 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-03 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-04 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-10 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-11 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-12 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-15 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-16 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-17 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-18 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-19 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-22 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-23 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-24 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-25 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-26 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-30 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-05-31 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-01 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-02 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-05 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-06 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-07 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-08 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-09 00:00:00-04:00    False
#  dtype: bool,
#       Date
#  MMM  2023-06-12 00:00:00-04:00    False
#  dtype: bool,
#  ...]

# %%
stocks = []
for value in stocks_to_buy_list:
    if value.any():
        stocks.append(value)
        print(value)
# Out:
#      Date
# MMM  2020-09-21 00:00:00-04:00    True
# dtype: bool
#      Date
# MMM  2022-10-25 00:00:00-04:00    True
# dtype: bool
#      Date
# ABT  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# ABT  2022-10-19 00:00:00-04:00    True
# dtype: bool
#       Date
# ABBV  2022-02-22 00:00:00-05:00    True
# dtype: bool
#       Date
# ABBV  2022-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# ABBV  2022-10-28 00:00:00-04:00    True
# dtype: bool
#       Date
# ABBV  2023-04-26 00:00:00-04:00    True
# dtype: bool
#      Date
# ACN  2021-07-19 00:00:00-04:00    True
# dtype: bool
#       Date
# ADBE  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# ADBE  2021-11-23 00:00:00-05:00    True
# dtype: bool
#      Date
# AMD  2021-07-08 00:00:00-04:00    True
# dtype: bool
#      Date
# AES  2023-04-17 00:00:00-04:00    True
# dtype: bool
#      Date
# AFL  2021-12-14 00:00:00-05:00    True
# dtype: bool
#    Date
# A  2023-07-25 00:00:00-04:00    True
# dtype: bool
#      Date
# APD  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# APD  2020-11-11 00:00:00-05:00    True
# dtype: bool
#      Date
# APD  2021-11-04 00:00:00-04:00    True
# dtype: bool
#       Date
# ABNB  2021-09-13 00:00:00-04:00    True
# dtype: bool
#       Date
# AKAM  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# AKAM  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# ALB  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# ALB  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# ALB  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# ALB  2024-03-05 00:00:00-05:00    True
# dtype: bool
#      Date
# ARE  2021-06-15 00:00:00-04:00    True
# dtype: bool
#       Date
# ALGN  2020-01-14 00:00:00-05:00    True
# dtype: bool
#       Date
# ALLE  2020-02-18 00:00:00-05:00    True
# dtype: bool
#       Date
# ALLE  2024-02-13 00:00:00-05:00    True
# dtype: bool
#       Date
# ALLE  2024-02-20 00:00:00-05:00    True
# dtype: bool
#        Date
# GOOGL  2020-01-27 00:00:00-05:00    True
# dtype: bool
#        Date
# GOOGL  2021-07-08 00:00:00-04:00    True
# dtype: bool
#       Date
# GOOG  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# GOOG  2023-02-03 00:00:00-05:00    True
# dtype: bool
#     Date
# MO  2022-03-04 00:00:00-05:00    True
# dtype: bool
#     Date
# MO  2023-04-27 00:00:00-04:00    True
# dtype: bool
#     Date
# MO  2023-12-06 00:00:00-05:00    True
# dtype: bool
#       Date
# AMZN  2022-07-26 00:00:00-04:00    True
# dtype: bool
#       Date
# AMZN  2023-01-25 00:00:00-05:00    True
# dtype: bool
#       Date
# AMZN  2023-02-03 00:00:00-05:00    True
# dtype: bool
#       Date
# AMZN  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# AEP  2021-04-22 00:00:00-04:00    True
# dtype: bool
#      Date
# AXP  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# AXP  2022-01-14 00:00:00-05:00    True
# dtype: bool
#      Date
# AIG  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# AMT  2022-06-02 00:00:00-04:00    True
# dtype: bool
#      Date
# AMP  2022-01-14 00:00:00-05:00    True
# dtype: bool
#      Date
# AME  2021-11-26 00:00:00-05:00    True
# dtype: bool
#      Date
# APH  2021-10-27 00:00:00-04:00    True
# dtype: bool
#      Date
# APH  2021-11-26 00:00:00-05:00    True
# dtype: bool
#      Date
# APH  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# ADI  2021-02-17 00:00:00-05:00    True
# dtype: bool
#      Date
# ADI  2021-09-28 00:00:00-04:00    True
# dtype: bool
#      Date
# ADI  2021-10-27 00:00:00-04:00    True
# dtype: bool
#      Date
# ADI  2023-07-20 00:00:00-04:00    True
# dtype: bool
#      Date
# ADI  2024-05-01 00:00:00-04:00    True
# dtype: bool
#       Date
# ANSS  2019-12-03 00:00:00-05:00    True
# dtype: bool
#       Date
# ANSS  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# AON  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# APA  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# AAPL  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# AAPL  2021-07-19 00:00:00-04:00    True
# dtype: bool
#       Date
# AAPL  2021-10-29 00:00:00-04:00    True
# dtype: bool
#       Date
# AAPL  2021-12-02 00:00:00-05:00    True
# dtype: bool
#       Date
# AMAT  2020-02-18 00:00:00-05:00    True
# dtype: bool
#       Date
# AMAT  2021-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# AMAT  2021-11-19 00:00:00-05:00    True
# dtype: bool
#       Date
# AMAT  2023-11-17 00:00:00-05:00    True
# dtype: bool
#       Date
# AMAT  2024-01-26 00:00:00-05:00    True
# dtype: bool
#       Date
# AMAT  2024-02-13 00:00:00-05:00    True
# dtype: bool
#       Date
# APTV  2022-08-04 00:00:00-04:00    True
# dtype: bool
#       Date
# ACGL  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# ACGL  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# ACGL  2021-11-26 00:00:00-05:00    True
# dtype: bool
#      Date
# ADM  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# ADM  2022-03-29 00:00:00-04:00    True
# dtype: bool
#       Date
# ANET  2020-08-05 00:00:00-04:00    True
# dtype: bool
#       Date
# ANET  2024-05-23 00:00:00-04:00    True
# dtype: bool
#      Date
# AJG  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# AIZ  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# AIZ  2022-02-24 00:00:00-05:00    True
# dtype: bool
#    Date
# T  2024-04-01 00:00:00-04:00    True
# dtype: bool
#      Date
# ATO  2021-02-22 00:00:00-05:00    True
# dtype: bool
#       Date
# ADSK  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# AZO  2024-02-08 00:00:00-05:00    True
# dtype: bool
#      Date
# AVY  2020-10-28 00:00:00-04:00    True
# dtype: bool
#      Date
# AVY  2024-01-02 00:00:00-05:00    True
# dtype: bool
#       Date
# AXON  2024-05-07 00:00:00-04:00    True
# dtype: bool
#       Date
# BALL  2020-10-28 00:00:00-04:00    True
# dtype: bool
#      Date
# BAC  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# BAC  2022-01-14 00:00:00-05:00    True
# dtype: bool
#     Date
# BK  2021-01-20 00:00:00-05:00    True
# dtype: bool
#     Date
# BK  2021-10-19 00:00:00-04:00    True
# dtype: bool
#       Date
# BBWI  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# BBWI  2023-11-16 00:00:00-05:00    True
# dtype: bool
#       Date
# BBWI  2024-02-29 00:00:00-05:00    True
# dtype: bool
#      Date
# BAX  2023-07-27 00:00:00-04:00    True
# dtype: bool
#      Date
# BDX  2023-05-04 00:00:00-04:00    True
# dtype: bool
#      Date
# BBY  2022-07-26 00:00:00-04:00    True
# dtype: bool
#      Date
# BBY  2022-11-16 00:00:00-05:00    True
# dtype: bool
#      Date
# BIO  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# BLK  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# BLK  2020-04-01 00:00:00-04:00    True
# dtype: bool
#      Date
# BLK  2021-01-14 00:00:00-05:00    True
# dtype: bool
#      Date
# BLK  2021-07-14 00:00:00-04:00    True
# dtype: bool
#      Date
# BLK  2022-06-10 00:00:00-04:00    True
# dtype: bool
#     Date
# BX  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# BX  2021-05-11 00:00:00-04:00    True
# dtype: bool
#     Date
# BX  2021-09-20 00:00:00-04:00    True
# dtype: bool
#     Date
# BX  2023-06-05 00:00:00-04:00    True
# dtype: bool
#     Date
# BX  2024-04-02 00:00:00-04:00    True
# dtype: bool
#     Date
# BA  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# BKNG  2022-06-10 00:00:00-04:00    True
# dtype: bool
#       Date
# BKNG  2022-08-22 00:00:00-04:00    True
# dtype: bool
#       Date
# BKNG  2023-01-25 00:00:00-05:00    True
# dtype: bool
#       Date
# BKNG  2024-02-23 00:00:00-05:00    True
# dtype: bool
#      Date
# BWA  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# BXP  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# BMY  2022-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# AVGO  2020-09-17 00:00:00-04:00    True
# dtype: bool
#     Date
# BR  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# BR  2024-05-08 00:00:00-04:00    True
# dtype: bool
#       Date
# BLDR  2020-02-21 00:00:00-05:00    True
# dtype: bool
#       Date
# BLDR  2021-05-11 00:00:00-04:00    True
# dtype: bool
#       Date
# BLDR  2024-02-13 00:00:00-05:00    True
# dtype: bool
#     Date
# BG  2021-09-20 00:00:00-04:00    True
# dtype: bool
#     Date
# BG  2022-03-29 00:00:00-04:00    True
# dtype: bool
#     Date
# BG  2022-07-27 00:00:00-04:00    True
# dtype: bool
#       Date
# CDNS  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# CZR  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# CPB  2020-03-09 00:00:00-04:00    True
# dtype: bool
#      Date
# COF  2022-10-28 00:00:00-04:00    True
# dtype: bool
#      Date
# COF  2023-01-19 00:00:00-05:00    True
# dtype: bool
#      Date
# CAH  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# CAH  2020-11-17 00:00:00-05:00    True
# dtype: bool
#      Date
# CAH  2022-01-10 00:00:00-05:00    True
# dtype: bool
#      Date
# CAH  2022-08-11 00:00:00-04:00    True
# dtype: bool
#      Date
# KMX  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# CCL  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# CCL  2022-07-21 00:00:00-04:00    True
# dtype: bool
#      Date
# CCL  2022-11-16 00:00:00-05:00    True
# dtype: bool
#       Date
# CARR  2022-11-03 00:00:00-04:00    True
# dtype: bool
#      Date
# CAT  2020-09-21 00:00:00-04:00    True
# dtype: bool
#      Date
# CAT  2022-08-02 00:00:00-04:00    True
# dtype: bool
#      Date
# CAT  2023-11-22 00:00:00-05:00    True
# dtype: bool
#       Date
# CBOE  2021-05-07 00:00:00-04:00    True
# dtype: bool
#       Date
# CBRE  2021-10-28 00:00:00-04:00    True
# dtype: bool
#      Date
# CDW  2021-08-13 00:00:00-04:00    True
# dtype: bool
#      Date
# CDW  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# COR  2020-11-17 00:00:00-05:00    True
# dtype: bool
#      Date
# COR  2021-05-05 00:00:00-04:00    True
# dtype: bool
#      Date
# COR  2022-11-08 00:00:00-05:00    True
# dtype: bool
#      Date
# COR  2022-12-09 00:00:00-05:00    True
# dtype: bool
#      Date
# CNC  2022-03-23 00:00:00-04:00    True
# dtype: bool
#      Date
# CNP  2023-12-15 00:00:00-05:00    True
# dtype: bool
#     Date
# CF  2020-06-11 00:00:00-04:00    True
# dtype: bool
#     Date
# CF  2021-09-20 00:00:00-04:00    True
# dtype: bool
#     Date
# CF  2021-11-26 00:00:00-05:00    True
# dtype: bool
#     Date
# CF  2022-03-29 00:00:00-04:00    True
# dtype: bool
#      Date
# CRL  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# CRL  2020-04-21 00:00:00-04:00    True
# dtype: bool
#       Date
# SCHW  2020-11-04 00:00:00-05:00    True
# dtype: bool
#       Date
# CHTR  2020-09-17 00:00:00-04:00    True
# dtype: bool
#      Date
# CVX  2022-01-24 00:00:00-05:00    True
# dtype: bool
#      Date
# CVX  2022-01-28 00:00:00-05:00    True
# dtype: bool
#      Date
# CVX  2022-03-15 00:00:00-04:00    True
# dtype: bool
#      Date
# CMG  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# CMG  2020-10-22 00:00:00-04:00    True
# dtype: bool
#      Date
# CMG  2023-02-08 00:00:00-05:00    True
# dtype: bool
#     Date
# CB  2020-06-11 00:00:00-04:00    True
# dtype: bool
#     Date
# CB  2020-11-04 00:00:00-05:00    True
# dtype: bool
#     Date
# CI  2022-07-14 00:00:00-04:00    True
# dtype: bool
#     Date
# CI  2023-06-14 00:00:00-04:00    True
# dtype: bool
#     Date
# CI  2023-08-03 00:00:00-04:00    True
# dtype: bool
#       Date
# CINF  2024-01-29 00:00:00-05:00    True
# dtype: bool
#       Date
# CTAS  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# CTAS  2024-03-01 00:00:00-05:00    True
# dtype: bool
#       Date
# CSCO  2021-02-10 00:00:00-05:00    True
# dtype: bool
#       Date
# CSCO  2023-04-06 00:00:00-04:00    True
# dtype: bool
#       Date
# CSCO  2023-07-28 00:00:00-04:00    True
# dtype: bool
#    Date
# C  2020-06-11 00:00:00-04:00    True
# dtype: bool
#    Date
# C  2022-01-14 00:00:00-05:00    True
# dtype: bool
#    Date
# C  2024-01-11 00:00:00-05:00    True
# dtype: bool
#      Date
# CFG  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# CFG  2023-08-08 00:00:00-04:00    True
# dtype: bool
#      Date
# CME  2021-11-26 00:00:00-05:00    True
# dtype: bool
#       Date
# CTSH  2020-05-08 00:00:00-04:00    True
# dtype: bool
#       Date
# CTSH  2020-09-17 00:00:00-04:00    True
# dtype: bool
#       Date
# CTSH  2023-02-03 00:00:00-05:00    True
# dtype: bool
#       Date
# CTSH  2023-07-20 00:00:00-04:00    True
# dtype: bool
#     Date
# CL  2022-10-28 00:00:00-04:00    True
# dtype: bool
#        Date
# CMCSA  2020-01-23 00:00:00-05:00    True
# dtype: bool
#        Date
# CMCSA  2020-09-17 00:00:00-04:00    True
# dtype: bool
#        Date
# CMCSA  2024-02-02 00:00:00-05:00    True
# dtype: bool
#      Date
# CMA  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# CAG  2021-10-08 00:00:00-04:00    True
# dtype: bool
#      Date
# COP  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# COP  2022-03-29 00:00:00-04:00    True
# dtype: bool
#      Date
# STZ  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# CEG  2022-11-08 00:00:00-05:00    True
# dtype: bool
#      Date
# COO  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# CPRT  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# GLW  2021-11-26 00:00:00-05:00    True
# dtype: bool
#      Date
# GLW  2023-07-14 00:00:00-04:00    True
# dtype: bool
#       Date
# CTVA  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# CTVA  2023-02-02 00:00:00-05:00    True
# dtype: bool
#       Date
# CSGP  2020-11-10 00:00:00-05:00    True
# dtype: bool
#       Date
# COST  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# COST  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# COST  2021-05-19 00:00:00-04:00    True
# dtype: bool
#       Date
# COST  2022-03-04 00:00:00-05:00    True
# dtype: bool
#       Date
# COST  2023-11-16 00:00:00-05:00    True
# dtype: bool
#       Date
# COST  2024-03-08 00:00:00-05:00    True
# dtype: bool
#       Date
# CTRA  2020-02-21 00:00:00-05:00    True
# dtype: bool
#       Date
# CTRA  2021-05-24 00:00:00-04:00    True
# dtype: bool
#      Date
# CSX  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# CMI  2023-12-22 00:00:00-05:00    True
# dtype: bool
#      Date
# CVS  2020-11-17 00:00:00-05:00    True
# dtype: bool
#      Date
# CVS  2022-02-09 00:00:00-05:00    True
# dtype: bool
#      Date
# DHR  2020-05-07 00:00:00-04:00    True
# dtype: bool
#      Date
# DHR  2023-07-25 00:00:00-04:00    True
# dtype: bool
#     Date
# DE  2020-02-24 00:00:00-05:00    True
# dtype: bool
#     Date
# DE  2021-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# DE  2024-05-16 00:00:00-04:00    True
# dtype: bool
#      Date
# DAL  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# DAL  2023-01-13 00:00:00-05:00    True
# dtype: bool
#      Date
# DVN  2023-08-02 00:00:00-04:00    True
# dtype: bool
#       Date
# DXCM  2020-10-02 00:00:00-04:00    True
# dtype: bool
#       Date
# DXCM  2021-02-12 00:00:00-05:00    True
# dtype: bool
#       Date
# DXCM  2021-04-30 00:00:00-04:00    True
# dtype: bool
#       Date
# DXCM  2023-03-06 00:00:00-05:00    True
# dtype: bool
#       Date
# FANG  2021-09-20 00:00:00-04:00    True
# dtype: bool
#       Date
# FANG  2023-08-08 00:00:00-04:00    True
# dtype: bool
#      Date
# DLR  2024-05-08 00:00:00-04:00    True
# dtype: bool
#      Date
# DFS  2022-07-21 00:00:00-04:00    True
# dtype: bool
#     Date
# DG  2022-01-06 00:00:00-05:00    True
# dtype: bool
#     Date
# DG  2024-03-13 00:00:00-04:00    True
# dtype: bool
#       Date
# DLTR  2020-08-27 00:00:00-04:00    True
# dtype: bool
#       Date
# DLTR  2023-11-16 00:00:00-05:00    True
# dtype: bool
#      Date
# DHI  2024-04-02 00:00:00-04:00    True
# dtype: bool
#      Date
# DUK  2022-07-14 00:00:00-04:00    True
# dtype: bool
#     Date
# DD  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# ETN  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# ETN  2021-07-19 00:00:00-04:00    True
# dtype: bool
#       Date
# EBAY  2020-02-07 00:00:00-05:00    True
# dtype: bool
#       Date
# EBAY  2020-04-30 00:00:00-04:00    True
# dtype: bool
#      Date
# ECL  2021-04-27 00:00:00-04:00    True
# dtype: bool
#      Date
# ECL  2022-11-01 00:00:00-04:00    True
# dtype: bool
#      Date
# EIX  2021-11-03 00:00:00-04:00    True
# dtype: bool
#      Date
# EIX  2024-04-10 00:00:00-04:00    True
# dtype: bool
#     Date
# EW  2022-07-29 00:00:00-04:00    True
# dtype: bool
#     Date
# EW  2023-04-27 00:00:00-04:00    True
# dtype: bool
#     Date
# EW  2023-06-20 00:00:00-04:00    True
# dtype: bool
#     Date
# EA  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# EA  2023-04-26 00:00:00-04:00    True
# dtype: bool
#      Date
# ELV  2023-11-29 00:00:00-05:00    True
# dtype: bool
#      Date
# LLY  2020-02-10 00:00:00-05:00    True
# dtype: bool
#      Date
# LLY  2024-02-21 00:00:00-05:00    True
# dtype: bool
#      Date
# LLY  2024-02-27 00:00:00-05:00    True
# dtype: bool
#      Date
# EMR  2022-08-09 00:00:00-04:00    True
# dtype: bool
#      Date
# ETR  2021-08-30 00:00:00-04:00    True
# dtype: bool
#      Date
# ETR  2024-04-24 00:00:00-04:00    True
# dtype: bool
#      Date
# EQT  2020-03-12 00:00:00-04:00    True
# dtype: bool
#      Date
# EQT  2021-09-29 00:00:00-04:00    True
# dtype: bool
#       Date
# EQIX  2021-04-22 00:00:00-04:00    True
# dtype: bool
#       Date
# EQIX  2021-11-04 00:00:00-04:00    True
# dtype: bool
#      Date
# EQR  2024-04-10 00:00:00-04:00    True
# dtype: bool
#     Date
# EL  2020-01-21 00:00:00-05:00    True
# dtype: bool
#     Date
# EL  2020-10-28 00:00:00-04:00    True
# dtype: bool
#     Date
# EL  2020-11-19 00:00:00-05:00    True
# dtype: bool
#       Date
# ETSY  2020-03-09 00:00:00-04:00    True
# dtype: bool
#       Date
# ETSY  2024-02-13 00:00:00-05:00    True
# dtype: bool
#     Date
# EG  2021-10-28 00:00:00-04:00    True
# dtype: bool
#     Date
# EG  2022-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# EVRG  2023-12-15 00:00:00-05:00    True
# dtype: bool
#      Date
# EXC  2020-10-28 00:00:00-04:00    True
# dtype: bool
#       Date
# EXPE  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# EXPD  2020-08-05 00:00:00-04:00    True
# dtype: bool
#       Date
# EXPD  2020-10-28 00:00:00-04:00    True
# dtype: bool
#       Date
# EXPD  2022-08-02 00:00:00-04:00    True
# dtype: bool
#      Date
# EXR  2020-02-19 00:00:00-05:00    True
# dtype: bool
#      Date
# XOM  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# XOM  2021-05-19 00:00:00-04:00    True
# dtype: bool
#      Date
# XOM  2022-06-13 00:00:00-04:00    True
# dtype: bool
#       Date
# FFIV  2020-05-01 00:00:00-04:00    True
# dtype: bool
#       Date
# FFIV  2021-04-08 00:00:00-04:00    True
# dtype: bool
#       Date
# FFIV  2023-11-16 00:00:00-05:00    True
# dtype: bool
#      Date
# FDS  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# FDS  2024-01-02 00:00:00-05:00    True
# dtype: bool
#      Date
# FDS  2024-03-21 00:00:00-04:00    True
# dtype: bool
#       Date
# FICO  2023-11-09 00:00:00-05:00    True
# dtype: bool
#       Date
# FICO  2024-01-26 00:00:00-05:00    True
# dtype: bool
#       Date
# FICO  2024-02-13 00:00:00-05:00    True
# dtype: bool
#       Date
# FAST  2020-10-13 00:00:00-04:00    True
# dtype: bool
#       Date
# FAST  2021-07-13 00:00:00-04:00    True
# dtype: bool
#      Date
# FRT  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# FDX  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# FDX  2023-07-24 00:00:00-04:00    True
# dtype: bool
#      Date
# FIS  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# FIS  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# FIS  2024-02-26 00:00:00-05:00    True
# dtype: bool
#       Date
# FITB  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# FITB  2021-09-20 00:00:00-04:00    True
# dtype: bool
#     Date
# FE  2022-04-22 00:00:00-04:00    True
# dtype: bool
#     Date
# FI  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# FI  2024-02-06 00:00:00-05:00    True
# dtype: bool
#      Date
# FMC  2020-02-24 00:00:00-05:00    True
# dtype: bool
#    Date
# F  2020-06-11 00:00:00-04:00    True
# dtype: bool
#    Date
# F  2020-10-28 00:00:00-04:00    True
# dtype: bool
#    Date
# F  2023-01-13 00:00:00-05:00    True
# dtype: bool
#    Date
# F  2023-02-03 00:00:00-05:00    True
# dtype: bool
#       Date
# FTNT  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# FTNT  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# FTV  2020-11-30 00:00:00-05:00    True
# dtype: bool
#       Date
# FOXA  2021-10-12 00:00:00-04:00    True
# dtype: bool
#      Date
# BEN  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# FCX  2021-05-19 00:00:00-04:00    True
# dtype: bool
#      Date
# FCX  2021-08-16 00:00:00-04:00    True
# dtype: bool
#      Date
# FCX  2022-06-10 00:00:00-04:00    True
# dtype: bool
#      Date
# FCX  2024-04-16 00:00:00-04:00    True
# dtype: bool
#      Date
# FCX  2024-05-22 00:00:00-04:00    True
# dtype: bool
#       Date
# GRMN  2021-04-28 00:00:00-04:00    True
# dtype: bool
#       Date
# GRMN  2021-05-11 00:00:00-04:00    True
# dtype: bool
#     Date
# GE  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# GEN  2020-11-06 00:00:00-05:00    True
# dtype: bool
#       Date
# GNRC  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# GNRC  2021-11-02 00:00:00-04:00    True
# dtype: bool
#     Date
# GD  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# GD  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# GIS  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# GIS  2021-03-24 00:00:00-04:00    True
# dtype: bool
#     Date
# GM  2020-10-28 00:00:00-04:00    True
# dtype: bool
#     Date
# GM  2023-01-13 00:00:00-05:00    True
# dtype: bool
#       Date
# GILD  2020-02-28 00:00:00-05:00    True
# dtype: bool
#       Date
# GILD  2021-07-30 00:00:00-04:00    True
# dtype: bool
#       Date
# GILD  2023-04-26 00:00:00-04:00    True
# dtype: bool
#      Date
# GPN  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# GPN  2020-02-12 00:00:00-05:00    True
# dtype: bool
#      Date
# GPN  2021-07-19 00:00:00-04:00    True
# dtype: bool
#     Date
# GL  2020-02-05 00:00:00-05:00    True
# dtype: bool
#     Date
# GL  2020-06-11 00:00:00-04:00    True
# dtype: bool
#     Date
# GS  2023-04-18 00:00:00-04:00    True
# dtype: bool
#      Date
# HAL  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# HAL  2024-01-30 00:00:00-05:00    True
# dtype: bool
#      Date
# HIG  2021-03-29 00:00:00-04:00    True
# dtype: bool
#      Date
# HIG  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# HIG  2022-10-28 00:00:00-04:00    True
# dtype: bool
#      Date
# HAS  2020-10-26 00:00:00-04:00    True
# dtype: bool
#      Date
# HAS  2024-04-10 00:00:00-04:00    True
# dtype: bool
#      Date
# HCA  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# DOC  2020-04-15 00:00:00-04:00    True
# dtype: bool
#       Date
# HSIC  2019-11-20 00:00:00-05:00    True
# dtype: bool
#       Date
# HSIC  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# HSIC  2023-02-16 00:00:00-05:00    True
# dtype: bool
#      Date
# HES  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# HPE  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# HPE  2021-11-12 00:00:00-05:00    True
# dtype: bool
#      Date
# HPE  2024-05-31 00:00:00-04:00    True
# dtype: bool
#       Date
# HOLX  2019-11-26 00:00:00-05:00    True
# dtype: bool
#     Date
# HD  2020-02-24 00:00:00-05:00    True
# dtype: bool
#     Date
# HD  2022-06-07 00:00:00-04:00    True
# dtype: bool
#     Date
# HD  2022-07-26 00:00:00-04:00    True
# dtype: bool
#     Date
# HD  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# HON  2021-04-23 00:00:00-04:00    True
# dtype: bool
#      Date
# HON  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# HST  2019-12-12 00:00:00-05:00    True
# dtype: bool
#      Date
# HWM  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# HPQ  2020-02-27 00:00:00-05:00    True
# dtype: bool
#      Date
# HPQ  2020-05-28 00:00:00-04:00    True
# dtype: bool
#      Date
# HPQ  2021-05-11 00:00:00-04:00    True
# dtype: bool
#      Date
# HPQ  2022-03-31 00:00:00-04:00    True
# dtype: bool
#       Date
# HUBB  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# HII  2021-10-26 00:00:00-04:00    True
# dtype: bool
#      Date
# HII  2022-11-03 00:00:00-04:00    True
# dtype: bool
#      Date
# IBM  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# IBM  2020-04-21 00:00:00-04:00    True
# dtype: bool
#       Date
# IDXX  2023-08-01 00:00:00-04:00    True
# dtype: bool
#      Date
# ITW  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# ITW  2021-11-26 00:00:00-05:00    True
# dtype: bool
#      Date
# ITW  2023-05-02 00:00:00-04:00    True
# dtype: bool
#      Date
# ITW  2023-08-01 00:00:00-04:00    True
# dtype: bool
#       Date
# ILMN  2021-08-06 00:00:00-04:00    True
# dtype: bool
#     Date
# IR  2020-02-24 00:00:00-05:00    True
# dtype: bool
#     Date
# IR  2021-11-26 00:00:00-05:00    True
# dtype: bool
#     Date
# IR  2024-02-13 00:00:00-05:00    True
# dtype: bool
#       Date
# PODD  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# PODD  2020-05-13 00:00:00-04:00    True
# dtype: bool
#      Date
# ICE  2020-03-06 00:00:00-05:00    True
# dtype: bool
#      Date
# ICE  2022-02-10 00:00:00-05:00    True
# dtype: bool
#     Date
# IP  2019-12-10 00:00:00-05:00    True
# dtype: bool
#     Date
# IP  2020-04-30 00:00:00-04:00    True
# dtype: bool
#       Date
# INTU  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# ISRG  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# IVZ  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# IVZ  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# IVZ  2023-07-25 00:00:00-04:00    True
# dtype: bool
#      Date
# IQV  2023-05-24 00:00:00-04:00    True
# dtype: bool
#      Date
# IQV  2023-06-20 00:00:00-04:00    True
# dtype: bool
#       Date
# JBHT  2019-06-21 00:00:00-04:00    True
# dtype: bool
#       Date
# JBHT  2020-04-21 00:00:00-04:00    True
# dtype: bool
#      Date
# JBL  2024-06-20 00:00:00-04:00    True
# dtype: bool
#       Date
# JKHY  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# JKHY  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# JKHY  2020-04-08 00:00:00-04:00    True
# dtype: bool
#       Date
# JKHY  2020-08-19 00:00:00-04:00    True
# dtype: bool
#    Date
# J  2022-08-01 00:00:00-04:00    True
# dtype: bool
#      Date
# JNJ  2020-01-22 00:00:00-05:00    True
# dtype: bool
#      Date
# JNJ  2020-10-13 00:00:00-04:00    True
# dtype: bool
#      Date
# JNJ  2021-01-29 00:00:00-05:00    True
# dtype: bool
#      Date
# JNJ  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# JNJ  2023-07-31 00:00:00-04:00    True
# dtype: bool
#      Date
# JCI  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# JCI  2021-01-11 00:00:00-05:00    True
# dtype: bool
#      Date
# JCI  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# JCI  2023-12-12 00:00:00-05:00    True
# dtype: bool
#      Date
# JPM  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# JPM  2023-01-13 00:00:00-05:00    True
# dtype: bool
#      Date
# KDP  2021-01-29 00:00:00-05:00    True
# dtype: bool
#      Date
# KDP  2022-10-27 00:00:00-04:00    True
# dtype: bool
#      Date
# KEY  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# KEYS  2024-05-21 00:00:00-04:00    True
# dtype: bool
#      Date
# KMB  2020-01-23 00:00:00-05:00    True
# dtype: bool
#      Date
# KIM  2020-04-15 00:00:00-04:00    True
# dtype: bool
#      Date
# KIM  2020-06-09 00:00:00-04:00    True
# dtype: bool
#      Date
# KIM  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# KLAC  2020-10-15 00:00:00-04:00    True
# dtype: bool
#       Date
# KLAC  2023-11-17 00:00:00-05:00    True
# dtype: bool
#       Date
# KLAC  2024-01-26 00:00:00-05:00    True
# dtype: bool
#       Date
# KLAC  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# KHC  2024-04-24 00:00:00-04:00    True
# dtype: bool
#     Date
# KR  2020-03-09 00:00:00-04:00    True
# dtype: bool
#      Date
# LHX  2021-10-26 00:00:00-04:00    True
# dtype: bool
#      Date
# LHX  2022-10-28 00:00:00-04:00    True
# dtype: bool
#     Date
# LH  2020-04-29 00:00:00-04:00    True
# dtype: bool
#     Date
# LH  2022-10-27 00:00:00-04:00    True
# dtype: bool
#       Date
# LRCX  2020-02-18 00:00:00-05:00    True
# dtype: bool
#       Date
# LRCX  2022-11-16 00:00:00-05:00    True
# dtype: bool
#       Date
# LRCX  2024-02-13 00:00:00-05:00    True
# dtype: bool
#     Date
# LW  2024-04-01 00:00:00-04:00    True
# dtype: bool
#       Date
# LDOS  2022-08-02 00:00:00-04:00    True
# dtype: bool
#       Date
# LDOS  2023-02-14 00:00:00-05:00    True
# dtype: bool
#      Date
# LEN  2024-03-14 00:00:00-04:00    True
# dtype: bool
#      Date
# LIN  2023-07-05 00:00:00-04:00    True
# dtype: bool
#      Date
# LYV  2020-12-21 00:00:00-05:00    True
# dtype: bool
#      Date
# LYV  2024-05-23 00:00:00-04:00    True
# dtype: bool
#      Date
# LKQ  2021-11-26 00:00:00-05:00    True
# dtype: bool
#      Date
# LKQ  2022-11-01 00:00:00-04:00    True
# dtype: bool
#      Date
# LMT  2022-03-09 00:00:00-05:00    True
# dtype: bool
#      Date
# LOW  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# LOW  2022-07-26 00:00:00-04:00    True
# dtype: bool
#      Date
# LOW  2023-11-21 00:00:00-05:00    True
# dtype: bool
#      Date
# LYB  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# LYB  2022-06-10 00:00:00-04:00    True
# dtype: bool
#      Date
# LYB  2023-04-13 00:00:00-04:00    True
# dtype: bool
#      Date
# MTB  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# MRO  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# MRO  2022-02-15 00:00:00-05:00    True
# dtype: bool
#      Date
# MPC  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# MPC  2022-06-13 00:00:00-04:00    True
# dtype: bool
#      Date
# MAR  2020-01-03 00:00:00-05:00    True
# dtype: bool
#      Date
# MAR  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# MMC  2020-01-30 00:00:00-05:00    True
# dtype: bool
#      Date
# MMC  2021-12-09 00:00:00-05:00    True
# dtype: bool
#      Date
# MLM  2020-10-13 00:00:00-04:00    True
# dtype: bool
#      Date
# MLM  2021-12-20 00:00:00-05:00    True
# dtype: bool
#     Date
# MA  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# MA  2021-07-19 00:00:00-04:00    True
# dtype: bool
#     Date
# MA  2022-02-10 00:00:00-05:00    True
# dtype: bool
#       Date
# MTCH  2023-02-01 00:00:00-05:00    True
# dtype: bool
#      Date
# MKC  2019-12-10 00:00:00-05:00    True
# dtype: bool
#      Date
# MCD  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# MCD  2020-09-21 00:00:00-04:00    True
# dtype: bool
#      Date
# MCK  2020-11-17 00:00:00-05:00    True
# dtype: bool
#      Date
# MCK  2023-08-17 00:00:00-04:00    True
# dtype: bool
#      Date
# MDT  2024-05-23 00:00:00-04:00    True
# dtype: bool
#       Date
# META  2024-01-31 00:00:00-05:00    True
# dtype: bool
#      Date
# MET  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# MGM  2020-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# MGM  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# MGM  2024-02-13 00:00:00-05:00    True
# dtype: bool
#     Date
# MU  2021-12-02 00:00:00-05:00    True
# dtype: bool
#     Date
# MU  2022-11-16 00:00:00-05:00    True
# dtype: bool
#     Date
# MU  2023-01-31 00:00:00-05:00    True
# dtype: bool
#     Date
# MU  2023-03-31 00:00:00-04:00    True
# dtype: bool
#     Date
# MU  2023-05-31 00:00:00-04:00    True
# dtype: bool
#     Date
# MU  2023-11-28 00:00:00-05:00    True
# dtype: bool
#       Date
# MSFT  2021-04-28 00:00:00-04:00    True
# dtype: bool
#       Date
# MSFT  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# MAA  2021-08-03 00:00:00-04:00    True
# dtype: bool
#       Date
# MRNA  2022-11-03 00:00:00-04:00    True
# dtype: bool
#      Date
# MHK  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# MHK  2021-10-29 00:00:00-04:00    True
# dtype: bool
#      Date
# MHK  2023-01-17 00:00:00-05:00    True
# dtype: bool
#      Date
# MHK  2024-02-09 00:00:00-05:00    True
# dtype: bool
#      Date
# MOH  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# MOH  2022-02-10 00:00:00-05:00    True
# dtype: bool
#       Date
# MDLZ  2021-07-28 00:00:00-04:00    True
# dtype: bool
#       Date
# MDLZ  2024-01-31 00:00:00-05:00    True
# dtype: bool
#       Date
# MPWR  2021-10-29 00:00:00-04:00    True
# dtype: bool
#       Date
# MPWR  2023-07-20 00:00:00-04:00    True
# dtype: bool
#       Date
# MPWR  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# MCO  2020-04-30 00:00:00-04:00    True
# dtype: bool
#     Date
# MS  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# MS  2021-05-19 00:00:00-04:00    True
# dtype: bool
#     Date
# MS  2023-04-19 00:00:00-04:00    True
# dtype: bool
#     Date
# MS  2024-03-06 00:00:00-05:00    True
# dtype: bool
#      Date
# MOS  2022-03-29 00:00:00-04:00    True
# dtype: bool
#      Date
# MSI  2020-10-28 00:00:00-04:00    True
# dtype: bool
#       Date
# MSCI  2020-04-01 00:00:00-04:00    True
# dtype: bool
#       Date
# MSCI  2022-02-08 00:00:00-05:00    True
# dtype: bool
#       Date
# MSCI  2022-06-01 00:00:00-04:00    True
# dtype: bool
#       Date
# MSCI  2022-09-13 00:00:00-04:00    True
# dtype: bool
#       Date
# NDAQ  2021-05-11 00:00:00-04:00    True
# dtype: bool
#       Date
# NTAP  2021-09-20 00:00:00-04:00    True
# dtype: bool
#       Date
# NTAP  2023-04-20 00:00:00-04:00    True
# dtype: bool
#       Date
# NTAP  2023-05-31 00:00:00-04:00    True
# dtype: bool
#       Date
# NFLX  2023-07-20 00:00:00-04:00    True
# dtype: bool
#      Date
# NEM  2020-11-09 00:00:00-05:00    True
# dtype: bool
#      Date
# NEM  2021-06-03 00:00:00-04:00    True
# dtype: bool
#      Date
# NEM  2021-10-28 00:00:00-04:00    True
# dtype: bool
#      Date
# NEM  2022-03-09 00:00:00-05:00    True
# dtype: bool
#      Date
# NEM  2022-03-29 00:00:00-04:00    True
# dtype: bool
#      Date
# NEM  2023-07-20 00:00:00-04:00    True
# dtype: bool
#      Date
# NWS  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# NEE  2020-01-24 00:00:00-05:00    True
# dtype: bool
#      Date
# NEE  2020-02-19 00:00:00-05:00    True
# dtype: bool
#      Date
# NEE  2020-09-16 00:00:00-04:00    True
# dtype: bool
#      Date
# NEE  2024-04-10 00:00:00-04:00    True
# dtype: bool
#      Date
# NKE  2020-04-01 00:00:00-04:00    True
# dtype: bool
#      Date
# NKE  2021-03-19 00:00:00-04:00    True
# dtype: bool
#     Date
# NI  2024-04-10 00:00:00-04:00    True
# dtype: bool
#       Date
# NDSN  2020-10-26 00:00:00-04:00    True
# dtype: bool
#      Date
# NSC  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# NSC  2023-07-21 00:00:00-04:00    True
# dtype: bool
#       Date
# NTRS  2023-01-19 00:00:00-05:00    True
# dtype: bool
#       Date
# NTRS  2023-08-08 00:00:00-04:00    True
# dtype: bool
#      Date
# NOC  2021-10-26 00:00:00-04:00    True
# dtype: bool
#      Date
# NOC  2022-10-27 00:00:00-04:00    True
# dtype: bool
#       Date
# NCLH  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# NCLH  2022-08-09 00:00:00-04:00    True
# dtype: bool
#      Date
# NUE  2020-04-15 00:00:00-04:00    True
# dtype: bool
#      Date
# NUE  2021-05-19 00:00:00-04:00    True
# dtype: bool
#      Date
# NUE  2022-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# NUE  2022-10-20 00:00:00-04:00    True
# dtype: bool
#       Date
# NVDA  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# NVDA  2022-08-08 00:00:00-04:00    True
# dtype: bool
#       Date
# NXPI  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# ORLY  2022-10-13 00:00:00-04:00    True
# dtype: bool
#      Date
# OXY  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# OXY  2021-05-11 00:00:00-04:00    True
# dtype: bool
#      Date
# OXY  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# OXY  2023-01-24 00:00:00-05:00    True
# dtype: bool
#       Date
# ODFL  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# ODFL  2020-08-25 00:00:00-04:00    True
# dtype: bool
#       Date
# ODFL  2021-10-27 00:00:00-04:00    True
# dtype: bool
#       Date
# ODFL  2022-07-13 00:00:00-04:00    True
# dtype: bool
#       Date
# ODFL  2023-07-24 00:00:00-04:00    True
# dtype: bool
#      Date
# OKE  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# OKE  2023-01-24 00:00:00-05:00    True
# dtype: bool
#       Date
# ORCL  2021-03-11 00:00:00-05:00    True
# dtype: bool
#       Date
# ORCL  2021-12-17 00:00:00-05:00    True
# dtype: bool
#       Date
# PCAR  2021-10-26 00:00:00-04:00    True
# dtype: bool
#       Date
# PANW  2024-02-13 00:00:00-05:00    True
# dtype: bool
#       Date
# PANW  2024-05-21 00:00:00-04:00    True
# dtype: bool
#       Date
# PARA  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# PARA  2021-03-23 00:00:00-04:00    True
# dtype: bool
#       Date
# PARA  2021-03-24 00:00:00-04:00    True
# dtype: bool
#     Date
# PH  2020-02-24 00:00:00-05:00    True
# dtype: bool
#     Date
# PH  2022-06-10 00:00:00-04:00    True
# dtype: bool
#     Date
# PH  2023-12-28 00:00:00-05:00    True
# dtype: bool
#       Date
# PYPL  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# PNR  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# PNR  2023-07-14 00:00:00-04:00    True
# dtype: bool
#      Date
# PCG  2019-12-16 00:00:00-05:00    True
# dtype: bool
#      Date
# PCG  2020-10-12 00:00:00-04:00    True
# dtype: bool
#      Date
# PCG  2022-04-14 00:00:00-04:00    True
# dtype: bool
#     Date
# PM  2020-04-21 00:00:00-04:00    True
# dtype: bool
#     Date
# PM  2022-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# PNC  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# PNC  2021-10-15 00:00:00-04:00    True
# dtype: bool
#      Date
# PNC  2024-03-06 00:00:00-05:00    True
# dtype: bool
#       Date
# POOL  2020-11-09 00:00:00-05:00    True
# dtype: bool
#       Date
# POOL  2022-07-21 00:00:00-04:00    True
# dtype: bool
#      Date
# PPG  2021-12-20 00:00:00-05:00    True
# dtype: bool
#      Date
# PFG  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# PFG  2021-02-26 00:00:00-05:00    True
# dtype: bool
#      Date
# PFG  2021-05-07 00:00:00-04:00    True
# dtype: bool
#      Date
# PFG  2021-11-26 00:00:00-05:00    True
# dtype: bool
#      Date
# PFG  2022-11-17 00:00:00-05:00    True
# dtype: bool
#      Date
# PFG  2023-07-28 00:00:00-04:00    True
# dtype: bool
#      Date
# PGR  2020-02-19 00:00:00-05:00    True
# dtype: bool
#      Date
# PGR  2020-04-15 00:00:00-04:00    True
# dtype: bool
#      Date
# PGR  2020-10-15 00:00:00-04:00    True
# dtype: bool
#      Date
# PGR  2023-09-15 00:00:00-04:00    True
# dtype: bool
#      Date
# PLD  2020-04-21 00:00:00-04:00    True
# dtype: bool
#      Date
# PLD  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# PRU  2019-11-05 00:00:00-05:00    True
# dtype: bool
#      Date
# PRU  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# PRU  2022-11-03 00:00:00-04:00    True
# dtype: bool
#      Date
# PEG  2022-03-18 00:00:00-04:00    True
# dtype: bool
#      Date
# PSA  2022-08-05 00:00:00-04:00    True
# dtype: bool
#      Date
# PSA  2024-04-10 00:00:00-04:00    True
# dtype: bool
#      Date
# PHM  2024-04-02 00:00:00-04:00    True
# dtype: bool
#       Date
# QRVO  2024-05-01 00:00:00-04:00    True
# dtype: bool
#     Date
# RL  2022-02-24 00:00:00-05:00    True
# dtype: bool
#     Date
# RL  2024-03-04 00:00:00-05:00    True
# dtype: bool
#      Date
# RJF  2020-01-23 00:00:00-05:00    True
# dtype: bool
#      Date
# RJF  2021-10-21 00:00:00-04:00    True
# dtype: bool
#      Date
# RTX  2020-06-11 00:00:00-04:00    True
# dtype: bool
#    Date
# O  2024-04-10 00:00:00-04:00    True
# dtype: bool
#       Date
# REGN  2020-03-12 00:00:00-04:00    True
# dtype: bool
#       Date
# REGN  2021-11-05 00:00:00-04:00    True
# dtype: bool
#       Date
# REGN  2024-01-08 00:00:00-05:00    True
# dtype: bool
#     Date
# RF  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# RMD  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# RVTY  2019-10-31 00:00:00-04:00    True
# dtype: bool
#      Date
# RHI  2020-11-19 00:00:00-05:00    True
# dtype: bool
#      Date
# ROK  2022-11-02 00:00:00-04:00    True
# dtype: bool
#      Date
# ROP  2022-11-03 00:00:00-04:00    True
# dtype: bool
#       Date
# ROST  2020-08-19 00:00:00-04:00    True
# dtype: bool
#       Date
# ROST  2022-07-26 00:00:00-04:00    True
# dtype: bool
#       Date
# SPGI  2023-06-20 00:00:00-04:00    True
# dtype: bool
#      Date
# CRM  2022-06-13 00:00:00-04:00    True
# dtype: bool
#      Date
# CRM  2023-06-01 00:00:00-04:00    True
# dtype: bool
#      Date
# SLB  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# STX  2019-11-01 00:00:00-04:00    True
# dtype: bool
#      Date
# STX  2021-05-19 00:00:00-04:00    True
# dtype: bool
#      Date
# STX  2022-07-22 00:00:00-04:00    True
# dtype: bool
#      Date
# STX  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# NOW  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# SHW  2019-11-18 00:00:00-05:00    True
# dtype: bool
#      Date
# SHW  2024-01-02 00:00:00-05:00    True
# dtype: bool
#      Date
# SPG  2021-05-11 00:00:00-04:00    True
# dtype: bool
#      Date
# SPG  2024-02-13 00:00:00-05:00    True
# dtype: bool
#       Date
# SWKS  2019-11-13 00:00:00-05:00    True
# dtype: bool
#     Date
# SO  2022-07-14 00:00:00-04:00    True
# dtype: bool
#      Date
# LUV  2020-01-30 00:00:00-05:00    True
# dtype: bool
#      Date
# LUV  2021-10-11 00:00:00-04:00    True
# dtype: bool
#      Date
# SWK  2020-04-30 00:00:00-04:00    True
# dtype: bool
#       Date
# SBUX  2020-12-21 00:00:00-05:00    True
# dtype: bool
#       Date
# SBUX  2021-07-28 00:00:00-04:00    True
# dtype: bool
#       Date
# SBUX  2021-09-15 00:00:00-04:00    True
# dtype: bool
#       Date
# SBUX  2022-04-04 00:00:00-04:00    True
# dtype: bool
#       Date
# SBUX  2023-05-03 00:00:00-04:00    True
# dtype: bool
#       Date
# STLD  2020-10-20 00:00:00-04:00    True
# dtype: bool
#       Date
# STLD  2021-05-19 00:00:00-04:00    True
# dtype: bool
#       Date
# STLD  2022-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# SYK  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# SYF  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# SYF  2020-10-20 00:00:00-04:00    True
# dtype: bool
#       Date
# SNPS  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# SNPS  2020-02-20 00:00:00-05:00    True
# dtype: bool
#       Date
# SNPS  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# SYY  2019-11-18 00:00:00-05:00    True
# dtype: bool
#      Date
# SYY  2020-09-21 00:00:00-04:00    True
# dtype: bool
#       Date
# TMUS  2020-11-10 00:00:00-05:00    True
# dtype: bool
#       Date
# TROW  2021-05-19 00:00:00-04:00    True
# dtype: bool
#       Date
# TROW  2021-11-03 00:00:00-04:00    True
# dtype: bool
#       Date
# TROW  2023-08-02 00:00:00-04:00    True
# dtype: bool
#       Date
# TTWO  2021-02-09 00:00:00-05:00    True
# dtype: bool
#      Date
# TPR  2020-02-07 00:00:00-05:00    True
# dtype: bool
#       Date
# TRGP  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# TRGP  2022-03-09 00:00:00-05:00    True
# dtype: bool
#      Date
# TGT  2022-07-26 00:00:00-04:00    True
# dtype: bool
#      Date
# TEL  2021-05-11 00:00:00-04:00    True
# dtype: bool
#      Date
# TEL  2022-11-02 00:00:00-04:00    True
# dtype: bool
#      Date
# TEL  2023-01-25 00:00:00-05:00    True
# dtype: bool
#      Date
# TDY  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# TER  2023-07-20 00:00:00-04:00    True
# dtype: bool
#       Date
# TSLA  2019-11-22 00:00:00-05:00    True
# dtype: bool
#       Date
# TSLA  2020-01-16 00:00:00-05:00    True
# dtype: bool
#       Date
# TSLA  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# TSLA  2021-01-28 00:00:00-05:00    True
# dtype: bool
#       Date
# TSLA  2021-11-08 00:00:00-05:00    True
# dtype: bool
#       Date
# TSLA  2023-07-20 00:00:00-04:00    True
# dtype: bool
#      Date
# TXN  2024-01-24 00:00:00-05:00    True
# dtype: bool
#      Date
# TXT  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# TXT  2022-06-10 00:00:00-04:00    True
# dtype: bool
#      Date
# TMO  2021-07-28 00:00:00-04:00    True
# dtype: bool
#      Date
# TMO  2021-11-05 00:00:00-04:00    True
# dtype: bool
#      Date
# TMO  2023-04-19 00:00:00-04:00    True
# dtype: bool
#      Date
# TJX  2022-04-22 00:00:00-04:00    True
# dtype: bool
#      Date
# TJX  2022-07-26 00:00:00-04:00    True
# dtype: bool
#      Date
# TJX  2023-11-15 00:00:00-05:00    True
# dtype: bool
#      Date
# TJX  2024-05-23 00:00:00-04:00    True
# dtype: bool
#     Date
# TT  2020-02-24 00:00:00-05:00    True
# dtype: bool
#     Date
# TT  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# TDG  2019-11-19 00:00:00-05:00    True
# dtype: bool
#      Date
# TDG  2020-01-27 00:00:00-05:00    True
# dtype: bool
#      Date
# TDG  2024-05-07 00:00:00-04:00    True
# dtype: bool
#      Date
# TRV  2020-11-04 00:00:00-05:00    True
# dtype: bool
#       Date
# TRMB  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# TRMB  2022-08-05 00:00:00-04:00    True
# dtype: bool
#      Date
# TFC  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# TYL  2020-02-18 00:00:00-05:00    True
# dtype: bool
#      Date
# USB  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# UBER  2020-01-27 00:00:00-05:00    True
# dtype: bool
#       Date
# UBER  2022-09-16 00:00:00-04:00    True
# dtype: bool
#       Date
# UBER  2023-01-24 00:00:00-05:00    True
# dtype: bool
#       Date
# UBER  2023-02-10 00:00:00-05:00    True
# dtype: bool
#      Date
# UDR  2021-02-10 00:00:00-05:00    True
# dtype: bool
#      Date
# UDR  2024-05-01 00:00:00-04:00    True
# dtype: bool
#       Date
# ULTA  2020-02-24 00:00:00-05:00    True
# dtype: bool
#       Date
# ULTA  2021-10-19 00:00:00-04:00    True
# dtype: bool
#      Date
# UNP  2020-09-21 00:00:00-04:00    True
# dtype: bool
#      Date
# UAL  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# UAL  2022-07-21 00:00:00-04:00    True
# dtype: bool
#      Date
# UAL  2024-03-25 00:00:00-04:00    True
# dtype: bool
#      Date
# UPS  2023-12-20 00:00:00-05:00    True
# dtype: bool
#      Date
# URI  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# UNH  2020-10-14 00:00:00-04:00    True
# dtype: bool
#       Date
# VRSN  2020-01-27 00:00:00-05:00    True
# dtype: bool
#     Date
# VZ  2022-04-22 00:00:00-04:00    True
# dtype: bool
#       Date
# VTRS  2023-06-23 00:00:00-04:00    True
# dtype: bool
#       Date
# VICI  2021-09-09 00:00:00-04:00    True
# dtype: bool
#       Date
# VICI  2024-04-10 00:00:00-04:00    True
# dtype: bool
#    Date
# V  2020-01-27 00:00:00-05:00    True
# dtype: bool
#    Date
# V  2021-07-19 00:00:00-04:00    True
# dtype: bool
#    Date
# V  2024-01-26 00:00:00-05:00    True
# dtype: bool
#      Date
# VMC  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# WRB  2021-07-19 00:00:00-04:00    True
# dtype: bool
#      Date
# WRB  2022-10-25 00:00:00-04:00    True
# dtype: bool
#      Date
# GWW  2023-12-20 00:00:00-05:00    True
# dtype: bool
#      Date
# GWW  2024-02-13 00:00:00-05:00    True
# dtype: bool
#      Date
# WAB  2022-06-10 00:00:00-04:00    True
# dtype: bool
#      Date
# WBA  2020-11-17 00:00:00-05:00    True
# dtype: bool
#      Date
# WBD  2021-03-23 00:00:00-04:00    True
# dtype: bool
#     Date
# WM  2021-10-26 00:00:00-04:00    True
# dtype: bool
#     Date
# WM  2023-12-15 00:00:00-05:00    True
# dtype: bool
#      Date
# WAT  2022-02-10 00:00:00-05:00    True
# dtype: bool
#      Date
# WAT  2022-08-02 00:00:00-04:00    True
# dtype: bool
#      Date
# WAT  2023-06-20 00:00:00-04:00    True
# dtype: bool
#      Date
# WFC  2020-06-11 00:00:00-04:00    True
# dtype: bool
#      Date
# WFC  2021-01-15 00:00:00-05:00    True
# dtype: bool
#       Date
# WELL  2020-06-11 00:00:00-04:00    True
# dtype: bool
#       Date
# WELL  2023-11-07 00:00:00-05:00    True
# dtype: bool
#      Date
# WST  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# WDC  2021-02-23 00:00:00-05:00    True
# dtype: bool
#      Date
# WDC  2021-05-19 00:00:00-04:00    True
# dtype: bool
#      Date
# WRK  2020-10-26 00:00:00-04:00    True
# dtype: bool
#      Date
# WRK  2021-05-05 00:00:00-04:00    True
# dtype: bool
#     Date
# WY  2020-05-01 00:00:00-04:00    True
# dtype: bool
#     Date
# WY  2021-04-30 00:00:00-04:00    True
# dtype: bool
#     Date
# WY  2022-10-28 00:00:00-04:00    True
# dtype: bool
#      Date
# WMB  2021-09-20 00:00:00-04:00    True
# dtype: bool
#      Date
# WMB  2022-04-25 00:00:00-04:00    True
# dtype: bool
#      Date
# WTW  2020-02-06 00:00:00-05:00    True
# dtype: bool
#      Date
# XYL  2019-10-31 00:00:00-04:00    True
# dtype: bool
#      Date
# XYL  2020-02-24 00:00:00-05:00    True
# dtype: bool
#      Date
# YUM  2022-09-13 00:00:00-04:00    True
# dtype: bool
#      Date
# ZBH  2020-08-04 00:00:00-04:00    True
# dtype: bool
#      Date
# ZBH  2021-05-04 00:00:00-04:00    True
# dtype: bool
#      Date
# ZBH  2023-11-07 00:00:00-05:00    True
# dtype: bool

# %%
df = pd.DataFrame(stocks)

df
# Out:
#                            MMM                            \
# Date 2020-09-21 00:00:00-04:00 2022-10-25 00:00:00-04:00
# 0                         True                       NaN
# 1                          NaN                      True
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#                            ABT                            \
# Date 2020-01-27 00:00:00-05:00 2022-10-19 00:00:00-04:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                         True                       NaN
# 3                          NaN                      True
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#                           ABBV                            \
# Date 2022-02-22 00:00:00-05:00 2022-02-24 00:00:00-05:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                         True                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#                                                           \
# Date 2022-10-28 00:00:00-04:00 2023-04-26 00:00:00-04:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#                            ACN                      ADBE  ...  \
# Date 2021-07-19 00:00:00-04:00 2020-01-27 00:00:00-05:00  ...
# 0                          NaN                       NaN  ...
# 1                          NaN                       NaN  ...
# 2                          NaN                       NaN  ...
# 3                          NaN                       NaN  ...
# 4                          NaN                       NaN  ...
# ..                         ...                       ...  ...
# 748                        NaN                       NaN  ...
# 749                        NaN                       NaN  ...
# 750                        NaN                       NaN  ...
# 751                        NaN                       NaN  ...
# 752                        NaN                       NaN  ...
#
#                             WY                       WMB  \
# Date 2022-10-28 00:00:00-04:00 2021-09-20 00:00:00-04:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#                                                      WTW  \
# Date 2022-04-25 00:00:00-04:00 2020-02-06 00:00:00-05:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#                            XYL                            \
# Date 2019-10-31 00:00:00-04:00 2020-02-24 00:00:00-05:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                      True
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#                            YUM                       ZBH  \
# Date 2022-09-13 00:00:00-04:00 2020-08-04 00:00:00-04:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                       True                       NaN
# 750                        NaN                      True
# 751                        NaN                       NaN
# 752                        NaN                       NaN
#
#
# Date 2021-05-04 00:00:00-04:00 2023-11-07 00:00:00-05:00
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ..                         ...                       ...
# 748                        NaN                       NaN
# 749                        NaN                       NaN
# 750                        NaN                       NaN
# 751                       True                       NaN
# 752                        NaN                      True
#
# [753 rows x 753 columns]

# %%
op_lo_df = pd.concat([op_lo,df],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 op_lo_df = pd.concat([op_lo,df],axis=1)
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:671, in _Concatenator.get_result(self)
#     669 for obj in self.objs:
#     670     indexers = {}
# --> 671     for ax, new_labels in enumerate(self.new_axes):
#     672         # ::-1 to convert BlockManager ax to DataFrame ax
#     673         if ax == self.bm_axis:
#     674             # Suppress reindexing on concat axis
#     675             continue
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:703, in _Concatenator.new_axes(self)
#     699 @cache_readonly
#     700 def new_axes(self) -> list[Index]:
#     701     ndim = self._get_result_dim()
#     702     return [
# --> 703         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     704         for i in range(ndim)
#     705     ]
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:709, in _Concatenator._get_comb_axis(self, i)
#     707 def _get_comb_axis(self, i: AxisInt) -> Index:
#     708     data_axis = self.objs[0]._get_block_manager_axis(i)
# --> 709     return get_objs_combined_axis(
#     710         self.objs,
#     711         axis=data_axis,
#     712         intersect=self.intersect,
#     713         sort=self.sort,
#     714         copy=self.copy,
#     715     )
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\api.py:103, in get_objs_combined_axis(objs, intersect, axis, sort, copy)
#      79 """
#      80 Extract combined index: return intersection or union (depending on the
#      81 value of "intersect") of indexes on given axis, or None if all objects
#    (...)
#     100 Index
#     101 """
#     102 obs_idxes = [obj._get_axis(axis) for obj in objs]
# --> 103 return _get_combined_index(obs_idxes, intersect=intersect, sort=sort, copy=copy)
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\api.py:156, in _get_combined_index(indexes, intersect, sort, copy)
#     154         index = index.intersection(other)
#     155 else:
# --> 156     index = union_indexes(indexes, sort=False)
#     157     index = ensure_index(index)
#     159 if sort:
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\api.py:312, in union_indexes(indexes, sort)
#     309         result = indexes[0]
#     311     for other in indexes[1:]:
# --> 312         result = result.union(other, sort=None if sort else False)
#     313     return result
#     315 elif kind == "array":
#
# File c:\Users\adebo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3331, in Index.union(self, other, sort)
#    3325 if self.dtype != other.dtype:
#    3326     if (
#    3327         isinstance(self, ABCMultiIndex)
#    3328         and not is_object_dtype(_unpack_nested_dtype(other))
#    3329         and len(other) > 0
#    3330     ):
# -> 3331         raise NotImplementedError(
#    3332             "Can only union MultiIndex with MultiIndex or Index of tuples, "
#    3333             "try mi.to_flat_index().union(other) instead."
#    3334         )
#    3335     self, other = self._dti_setop_align_tzs(other, "union")
#    3337     dtype = self._find_common_type_compat(other)
#
# NotImplementedError: Can only union MultiIndex with MultiIndex or Index of tuples, try mi.to_flat_index().union(other) instead.

# %%
ww = op_lo_df.dropna()

ww
# Out:
# Empty DataFrame
# Columns: [0, (MMM, 2020-09-21 00:00:00-04:00), (MMM, 2022-10-25 00:00:00-04:00), (ABT, 2020-01-27 00:00:00-05:00), (ABT, 2022-10-19 00:00:00-04:00), (ABBV, 2022-02-22 00:00:00-05:00), (ABBV, 2022-02-24 00:00:00-05:00), (ABBV, 2022-10-28 00:00:00-04:00), (ABBV, 2023-04-26 00:00:00-04:00), (ACN, 2021-07-19 00:00:00-04:00), (ADBE, 2020-01-27 00:00:00-05:00), (ADBE, 2021-11-23 00:00:00-05:00), (AMD, 2021-07-08 00:00:00-04:00), (AES, 2023-04-17 00:00:00-04:00), (AFL, 2021-12-14 00:00:00-05:00), (A, 2023-07-25 00:00:00-04:00), (APD, 2020-02-24 00:00:00-05:00), (APD, 2020-11-11 00:00:00-05:00), (APD, 2021-11-04 00:00:00-04:00), (ABNB, 2021-09-13 00:00:00-04:00), (AKAM, 2020-02-24 00:00:00-05:00), (AKAM, 2024-02-13 00:00:00-05:00), (ALB, 2020-02-24 00:00:00-05:00), (ALB, 2020-06-11 00:00:00-04:00), (ALB, 2021-07-19 00:00:00-04:00), (ALB, 2024-03-05 00:00:00-05:00), (ARE, 2021-06-15 00:00:00-04:00), (ALGN, 2020-01-14 00:00:00-05:00), (ALLE, 2020-02-18 00:00:00-05:00), (ALLE, 2024-02-13 00:00:00-05:00), (ALLE, 2024-02-20 00:00:00-05:00), (GOOGL, 2020-01-27 00:00:00-05:00), (GOOGL, 2021-07-08 00:00:00-04:00), (GOOG, 2020-01-27 00:00:00-05:00), (GOOG, 2023-02-03 00:00:00-05:00), (MO, 2022-03-04 00:00:00-05:00), (MO, 2023-04-27 00:00:00-04:00), (MO, 2023-12-06 00:00:00-05:00), (AMZN, 2022-07-26 00:00:00-04:00), (AMZN, 2023-01-25 00:00:00-05:00), (AMZN, 2023-02-03 00:00:00-05:00), (AMZN, 2024-02-13 00:00:00-05:00), (AEP, 2021-04-22 00:00:00-04:00), (AXP, 2020-01-27 00:00:00-05:00), (AXP, 2022-01-14 00:00:00-05:00), (AIG, 2020-06-11 00:00:00-04:00), (AMT, 2022-06-02 00:00:00-04:00), (AMP, 2022-01-14 00:00:00-05:00), (AME, 2021-11-26 00:00:00-05:00), (APH, 2021-10-27 00:00:00-04:00), (APH, 2021-11-26 00:00:00-05:00), (APH, 2024-02-13 00:00:00-05:00), (ADI, 2021-02-17 00:00:00-05:00), (ADI, 2021-09-28 00:00:00-04:00), (ADI, 2021-10-27 00:00:00-04:00), (ADI, 2023-07-20 00:00:00-04:00), (ADI, 2024-05-01 00:00:00-04:00), (ANSS, 2019-12-03 00:00:00-05:00), (ANSS, 2020-01-27 00:00:00-05:00), (AON, 2020-02-24 00:00:00-05:00), (APA, 2020-06-11 00:00:00-04:00), (AAPL, 2020-01-27 00:00:00-05:00), (AAPL, 2021-07-19 00:00:00-04:00), (AAPL, 2021-10-29 00:00:00-04:00), (AAPL, 2021-12-02 00:00:00-05:00), (AMAT, 2020-02-18 00:00:00-05:00), (AMAT, 2021-01-27 00:00:00-05:00), (AMAT, 2021-11-19 00:00:00-05:00), (AMAT, 2023-11-17 00:00:00-05:00), (AMAT, 2024-01-26 00:00:00-05:00), (AMAT, 2024-02-13 00:00:00-05:00), (APTV, 2022-08-04 00:00:00-04:00), (ACGL, 2020-01-27 00:00:00-05:00), (ACGL, 2020-02-24 00:00:00-05:00), (ACGL, 2021-11-26 00:00:00-05:00), (ADM, 2021-09-20 00:00:00-04:00), (ADM, 2022-03-29 00:00:00-04:00), (ANET, 2020-08-05 00:00:00-04:00), (ANET, 2024-05-23 00:00:00-04:00), (AJG, 2021-09-20 00:00:00-04:00), (AIZ, 2020-02-24 00:00:00-05:00), (AIZ, 2022-02-24 00:00:00-05:00), (T, 2024-04-01 00:00:00-04:00), (ATO, 2021-02-22 00:00:00-05:00), (ADSK, 2024-02-13 00:00:00-05:00), (AZO, 2024-02-08 00:00:00-05:00), (AVY, 2020-10-28 00:00:00-04:00), (AVY, 2024-01-02 00:00:00-05:00), (AXON, 2024-05-07 00:00:00-04:00), (BALL, 2020-10-28 00:00:00-04:00), (BAC, 2020-06-11 00:00:00-04:00), (BAC, 2022-01-14 00:00:00-05:00), (BK, 2021-01-20 00:00:00-05:00), (BK, 2021-10-19 00:00:00-04:00), (BBWI, 2020-06-11 00:00:00-04:00), (BBWI, 2023-11-16 00:00:00-05:00), (BBWI, 2024-02-29 00:00:00-05:00), (BAX, 2023-07-27 00:00:00-04:00), (BDX, 2023-05-04 00:00:00-04:00), (BBY, 2022-07-26 00:00:00-04:00), ...]
# Index: []
#
# [0 rows x 754 columns]

# %%
for t in range(1, len(df)):
    # Selecting the entire row for the current day 't'
    op_lo_today = op_lo.iloc[t, :]
    open_today = df['Open'].iloc[t, :]
    buy_price_today = buyPrice.iloc[t, :]
    moving_avg_today = moving_average.iloc[t, :]
    
    # Creating a boolean array for stocks to buy
    stocks_to_buy = op_lo_today.notnull() & (open_today < buy_price_today) & (open_today > moving_avg_today)
    
    # Selecting the stocks to buy and sorting them
    sort_data = op_lo_today[stocks_to_buy].sort_values()
    
    # Selecting the top N stocks
    sort_data = sort_data.head(min(topN, len(sort_data)))
    
    # Updating the position table for the selected stocks
    positionTable.iloc[t, sort_data.index] = 1
