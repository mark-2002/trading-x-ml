# %%
# %pip install --userstatsmodels
# %pip update --userstatsmodels
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Usage:
#   D:\PROGRAMMING\anaconda\python.exe -m pip install [options] <requirement specifier> [package-index-options] ...
#   D:\PROGRAMMING\anaconda\python.exe -m pip install [options] -r <requirements file> [package-index-options] ...
#   D:\PROGRAMMING\anaconda\python.exe -m pip install [options] [-e] <vcs project url> ...
#   D:\PROGRAMMING\anaconda\python.exe -m pip install [options] [-e] <local project path> ...
#   D:\PROGRAMMING\anaconda\python.exe -m pip install [options] <archive url/path> ...
#
# no such option: --userstatsmodels
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "update"

# %%
#%matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %config InlineBackend.figure_format = 'retina'

# %%
df = pd.read_csv("MU.csv")

df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2013-07-01  14.47  14.60  14.18  14.27  14.097193  33909600
# 1  2013-07-02  14.03  14.33  13.85  14.31  14.136708  61198800
# 2  2013-07-03  14.29  14.29  14.11  14.14  13.968767  24489300
# 3  2013-07-05  14.27  14.37  14.12  14.31  14.136708  29746900
# 4  2013-07-08  14.36  14.36  13.87  14.03  13.860099  53084600

# %%
df['Date'] = pd.to_datetime(df['Date'])
max_date = df['Date'].max()
min_date = df['Date'].min()

print(max_date,min_date)
# Out:
# 2023-06-28 00:00:00 2013-07-01 00:00:00

# %%
start_date_first_set = pd.to_datetime('2021-06-29')
end_date_first_set = pd.to_datetime('2023-06-29')


amazon_first_15_years_1997 = df[(df['Date'] >= start_date_first_set) & (df['Date'] <= end_date_first_set)]
amazon_first_15_years_1997
amazon_first_15_years_1997.set_index('Date', inplace=True)

# %%
amazon_first_15_years_1997 = amazon_first_15_years_1997.resample('w').mean()
amazon_first_15_years_1997 = amazon_first_15_years_1997[['Adj Close']]
amazon_first_15_years_1997.head()
# Out:
#             Adj Close
# Date
# 2021-07-04  81.093437
# 2021-07-11  77.833397
# 2021-07-18  76.745238
# 2021-07-25  74.808971
# 2021-08-01  75.223889

# %%
amazon_first_15_years_1997['weekly_returns'] = np.log(amazon_first_15_years_1997['Adj Close']).diff()
amazon_first_15_years_1997
# Out:
#             Adj Close  weekly_returns
# Date
# 2021-07-04  81.093437             NaN
# 2021-07-11  77.833397       -0.041031
# 2021-07-18  76.745238       -0.014079
# 2021-07-25  74.808971       -0.025554
# 2021-08-01  75.223889        0.005531
# ...               ...             ...
# 2023-06-04  69.537498        0.015587
# 2023-06-11  66.623999       -0.042801
# 2023-06-18  68.184001        0.023145
# 2023-06-25  66.057501       -0.031684
# 2023-07-02  66.436666        0.005724
#
# [105 rows x 2 columns]

# %%
amazon_first_15_years_1997.dropna(inplace=True)

# %%
amazon_first_15_years_1997.weekly_returns.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
udiff = amazon_first_15_years_1997.drop(['Adj Close'],axis=1) 
udiff.head()
# Out:
#             weekly_returns
# Date
# 2021-07-11       -0.041031
# 2021-07-18       -0.014079
# 2021-07-25       -0.025554
# 2021-08-01        0.005531
# 2021-08-08        0.059250

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
rolmean = udiff.rolling(20).mean()
rolstd = udiff.rolling(20).std()

# %%
plt.figure(figsize=(12,6))
plt.plot(udiff,color='blue',label='Original returns')
plt.plot(rolmean,color='red',label='Rolling Mean')
plt.plot(rolstd,color='black',label='Rolling Std Deviation ')
plt.legend(loc='best')
plt.show()

# %%
dftest = sm.tsa.adfuller(udiff.weekly_returns,autolag='AIC')
dfoutput = pd.Series(dftest[0:4],index=['Test Stats','p-value','No of Lags','No of Observation '])
dfoutput
# Out:
# Test Stats           -8.752210e+00
# p-value               2.816659e-14
# No of Lags            0.000000e+00
# No of Observation     1.030000e+02
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf
fig,ax = plt.subplots(figsize=(12,5))
plot_acf(udiff.values,lags=10,ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from statsmodels.graphics.tsaplots import plot_pacf
fig,ax = plt.subplots(figsize=(12,5))
plot_pacf(udiff.values,lags=10,ax=ax)
plt.show
# Out:
# d:\PROGRAMMING\anaconda\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
"""from statsmodels.tsa.arima_model import ARMA
ar1 =ARMA(tuple(udiff.values),(7,1)).fit()
ar1.summary()"""
# Out:
# 'from statsmodels.tsa.arima_model import ARMA\nar1 =ARMA(tuple(udiff.values),(7,1)).fit()\nar1.summary()'

# %%
"""plt.figure(figsize=(12,8))
plt.plot(udiff.values,color='blue')
preds=ar1.fittedvalues
plt.plot(preds,color='red')
plt.show()"""
# Out:
# "plt.figure(figsize=(12,8))\nplt.plot(udiff.values,color='blue')\npreds=ar1.fittedvalues\nplt.plot(preds,color='red')\nplt.show()"

# %%
"""steps=2
forecast = ar1.forecast(steps=steps)[0]
forecast"""
# Out:
# 'steps=2\nforecast = ar1.forecast(steps=steps)[0]\nforecast'

# %%
"""

plt.figure(figsize=(12, 8))
plt.plot(udiff.values, color='blue')

preds = ar1.fittedvalues
plt.plot(preds, color='red')

plt.plot(pd.DataFrame(np.array([preds[-1],forecast[0]]).T,index=range(len(udiff.values)+1, len(udiff.values)+3)), color='green')
plt.plot(pd.DataFrame(forecast,index=range(len(udiff.values)+1, len(udiff.values)+1+steps)), color='green')
plt.title('Display the predictions with the ARIMA model')
plt.show()"""
# Out:
# "\n\nplt.figure(figsize=(12, 8))\nplt.plot(udiff.values, color='blue')\n\npreds = ar1.fittedvalues\nplt.plot(preds, color='red')\n\nplt.plot(pd.DataFrame(np.array([preds[-1],forecast[0]]).T,index=range(len(udiff.values)+1, len(udiff.values)+3)), color='green')\nplt.plot(pd.DataFrame(forecast,index=range(len(udiff.values)+1, len(udiff.values)+1+steps)), color='green')\nplt.title('Display the predictions with the ARIMA model')\nplt.show()"

# %%
start_date_first_set = pd.to_datetime('2021-06-29')
end_date_first_set = pd.to_datetime('2023-06-29')


amazon_last_10_years_1997 = df[(df['Date'] >= start_date_first_set) & (df['Date'] <= end_date_first_set)]

amazon_last_10_years_1997.set_index('Date', inplace=True)
amazon_last_10_years_1997
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-06-29  83.540001  83.839996  81.870003  82.930000  81.925735  18530800
# 2021-06-30  84.849998  85.400002  83.430000  84.980003  83.950920  40670800
# 2021-07-01  82.239998  82.250000  79.910004  80.110001  79.139885  53299000
# 2021-07-02  80.610001  80.889999  78.889999  80.330002  79.357208  22685500
# 2021-07-06  80.790001  81.540001  79.760002  81.080002  80.098137  21126500
# ...               ...        ...        ...        ...        ...       ...
# 2023-06-22  65.529999  66.660004  65.510002  66.250000  66.250000   8639500
# 2023-06-23  65.449997  65.959999  64.839996  65.279999  65.279999  12646700
# 2023-06-26  65.629997  66.699997  65.410004  65.449997  65.449997  13815900
# 2023-06-27  65.269997  66.839996  63.790001  66.790001  66.790001  18305200
# 2023-06-28  65.650002  67.730003  65.389999  67.070000  67.070000  26689900
#
# [503 rows x 6 columns]

# %%
amazon_last_10_years_1997 = amazon_last_10_years_1997.resample('w').mean()
amazon_last_10_years_1997= amazon_last_10_years_1997[['Adj Close']]
amazon_last_10_years_1997.head()
# Out:
#             Adj Close
# Date
# 2021-07-04  81.093437
# 2021-07-11  77.833397
# 2021-07-18  76.745238
# 2021-07-25  74.808971
# 2021-08-01  75.223889

# %%
amazon_last_10_years_1997['weekly_returns'] = np.log(amazon_last_10_years_1997['Adj Close']).diff()
amazon_last_10_years_1997
# Out:
#             Adj Close  weekly_returns
# Date
# 2021-07-04  81.093437             NaN
# 2021-07-11  77.833397       -0.041031
# 2021-07-18  76.745238       -0.014079
# 2021-07-25  74.808971       -0.025554
# 2021-08-01  75.223889        0.005531
# ...               ...             ...
# 2023-06-04  69.537498        0.015587
# 2023-06-11  66.623999       -0.042801
# 2023-06-18  68.184001        0.023145
# 2023-06-25  66.057501       -0.031684
# 2023-07-02  66.436666        0.005724
#
# [105 rows x 2 columns]

# %%
amazon_last_10_years_1997.dropna(inplace=True)

# %%
amazon_last_10_years_1997.weekly_returns.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
udiff = amazon_last_10_years_1997.drop(['Adj Close'],axis=1) 
udiff.head()
# Out:
#             weekly_returns
# Date
# 2021-07-11       -0.041031
# 2021-07-18       -0.014079
# 2021-07-25       -0.025554
# 2021-08-01        0.005531
# 2021-08-08        0.059250

# %%
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller

# %%
rolmean = udiff.rolling(20).mean()
rolmean50 = udiff.rolling(50).mean()
rolstd = udiff.rolling(20).std()

rol = rolmean.dropna()
rol2 = rolmean50.dropna()
rol
# Out:
#             weekly_returns
# Date
# 2021-11-21       -0.002600
# 2021-11-28        0.003703
# 2021-12-05        0.003952
# 2021-12-12        0.005819
# 2021-12-19        0.004858
# ...                    ...
# 2023-06-04        0.009896
# 2023-06-11        0.007862
# 2023-06-18        0.004647
# 2023-06-25        0.003240
# 2023-07-02        0.004804
#
# [85 rows x 1 columns]

# %%
rol2
# Out:
#             weekly_returns
# Date
# 2022-06-19       -0.007049
# 2022-06-26       -0.006415
# 2022-07-03       -0.006357
# 2022-07-10       -0.005239
# 2022-07-17       -0.004870
# 2022-07-24       -0.005110
# 2022-07-31       -0.003832
# 2022-08-07       -0.002054
# 2022-08-14       -0.003166
# 2022-08-21       -0.003100
# 2022-08-28       -0.004277
# 2022-09-04       -0.005243
# 2022-09-11       -0.005356
# 2022-09-18       -0.005738
# 2022-09-25       -0.006520
# 2022-10-02       -0.005887
# 2022-10-09       -0.004623
# 2022-10-16       -0.005093
# 2022-10-23       -0.005592
# 2022-10-30       -0.006182
# 2022-11-06       -0.007027
# 2022-11-13       -0.007257
# 2022-11-20       -0.006518
# 2022-11-27       -0.007407
# 2022-12-04       -0.008025
# 2022-12-11       -0.009827
# 2022-12-18       -0.011038
# 2022-12-25       -0.012539
# 2023-01-01       -0.012790
# 2023-01-08       -0.009487
# 2023-01-15       -0.006748
# 2023-01-22       -0.007170
# 2023-01-29       -0.006487
# 2023-02-05       -0.008005
# 2023-02-12       -0.007621
# 2023-02-19       -0.007279
# 2023-02-26       -0.005338
# 2023-03-05       -0.005621
# 2023-03-12       -0.006457
# 2023-03-19       -0.007057
# 2023-03-26       -0.004331
# 2023-04-02       -0.003017
# 2023-04-09       -0.004004
# 2023-04-16       -0.001516
# 2023-04-23       -0.002811
# 2023-04-30       -0.002211
# 2023-05-07       -0.002705
# 2023-05-14       -0.002515
# 2023-05-21       -0.001956
# 2023-05-28        0.000394
# 2023-06-04        0.003974
# 2023-06-11        0.003305
# 2023-06-18        0.003991
# 2023-06-25        0.002751
# 2023-07-02        0.002385

# %%
plt.figure(figsize=(12,6))
plt.plot(udiff,color='blue',label='Original returns')
plt.plot(rolmean,color='red',label='Rolling Mean 20')
plt.plot(rolmean50,color='green',label='Rolling Mean 50')
plt.plot(rolstd,color='black',label='Rolling Std Deviation ')
plt.legend(loc='best')
plt.show()

# %%
dftest = sm.tsa.adfuller(udiff.weekly_returns,autolag='AIC')
dfoutput = pd.Series(dftest[0:4],index=['Test Stats','p-value','No of Lags','No of Observation '])
dfoutput
# Out:
# Test Stats           -8.752210e+00
# p-value               2.816659e-14
# No of Lags            0.000000e+00
# No of Observation     1.030000e+02
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf
fig,ax = plt.subplots(figsize=(12,5))
plot_acf(udiff.values,lags=10,ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from statsmodels.graphics.tsaplots import plot_pacf
fig,ax = plt.subplots(figsize=(12,5))
plot_pacf(udiff.values,lags=10,ax=ax)
plt.show
# Out:
# d:\PROGRAMMING\anaconda\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from statsmodels.tsa.arima_model import ARMA
ar1 =ARMA(tuple(udiff.values),(2,1)).fit()
ar1.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from statsmodels.tsa.arima_model import ARMA
# ----> 2 ar1 =ARMA(tuple(udiff.values),(2,1)).fit()
#       3 ar1.summary()
#
# NameError: name 'udiff' is not defined

# %%
plt.figure(figsize=(12,8))
plt.plot(udiff.values,color='blue')
preds=ar1.fittedvalues
plt.plot(preds,color='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 plt.figure(figsize=(12,8))
#       2 plt.plot(udiff.values,color='blue')
#       3 preds=ar1.fittedvalues
#
# NameError: name 'plt' is not defined

# %%
steps=12
forecast = ar1.forecast(steps=steps)[0]
forecast
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 2
#       1 steps=12
# ----> 2 forecast = ar1.forecast(steps=steps)[0]
#       3 forecast
#
# AttributeError: 'SARIMAX' object has no attribute 'forecast'

# %%
plt.figure(figsize=(12, 8))
plt.plot(udiff.values, color='blue')

preds = ar1.fittedvalues
plt.plot(preds, color='red')

plt.plot(pd.DataFrame(np.array([preds[-1],forecast[0]]).T,index=range(len(udiff.values)+1, len(udiff.values)+3)), color='green')
plt.plot(pd.DataFrame(forecast,index=range(len(udiff.values)+1, len(udiff.values)+1+steps)), color='green')
plt.title('Display the predictions with the ARIMA model')
plt.show()
